# %%
import gym

# %%
env = gym.make('Taxi-v3').env

# %%
a = env.reset()

# %%
print(a)
# Out:
# 173

# %%
env.s = env.reset()

# %%
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+

# %%
next_state  , reward , don , _  = env.step(1)

# %%
next_state
# Out:
# 4

# %%
env.s = 4
env.render()
# Out:
# +---------+
# |R: | : :G|
# | : | : : |
# | : : : : |
# | | : | : |
# |Y| : |B: |
# +---------+
#   (North)

# %%
next_state1 , reward , done ,_ = env.step(4)
env.P[4]
# Out:
# {0: [(1.0, 104, -1, False)],
#  1: [(1.0, 4, -1, False)],
#  2: [(1.0, 24, -1, False)],
#  3: [(1.0, 4, -1, False)],
#  4: [(1.0, 4, -10, False)],
#  5: [(1.0, 4, -10, False)]}

# %%
next_state1
# Out:
# 4
